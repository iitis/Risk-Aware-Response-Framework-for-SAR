# %%
from module_generated_response import RiskAwareResponseGenerator

generator = RiskAwareResponseGenerator(
    model_variant="deepseek-r1:14b",
    output_file="Results/robot_generated_responses_model_deepseek.json",
    excel_file="Data/Elderly_Query.xlsx",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

generator.run()
# Out:
# Generated: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Generated: What’s the weather like today?
# Generated: Can you open the curtains?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
# ...

# %%
from generated_response import RiskAwareResponseGenerator

generator = RiskAwareResponseGenerator(
    model_variant="phi4:14b",
    output_file="Results/robot_generated_responses_model_phi.json",
    excel_file="Data/Elderly_Query.xlsx",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

generator.run()
# Out:
# Generated: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Generated: What’s the weather like today?
# Generated: Can you open the curtains?
# Generated: Please turn off the television.
# Generated: Can you turn on the lights?
# Generated: Turn off the kitchen light.
# Generated: Can you play the radio?
# Generated: Please switch to the news channel.
# Generated: Lower the air conditioning a little.
# ...

# %%
from generated_response import RiskAwareResponseGenerator

generator = RiskAwareResponseGenerator(
    model_variant="llama3.1:8b",
    output_file="Results/robot_generated_responses_model_llama.json",
    excel_file="Data/Elderly_Query.xlsx",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

generator.run()
# Out:
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Generated: What time is it?
# Generated: What’s the weather like today?
# Generated: Can you open the curtains?
# Generated: Please turn off the television.
# Generated: Can you turn on the lights?
# Generated: Turn off the kitchen light.
# Generated: Can you play the radio?
# Generated: Please switch to the news channel.
# Generated: Lower the air conditioning a little.
# ...

# %%
from generated_response import RiskAwareResponseGenerator

generator = RiskAwareResponseGenerator(
    model_variant="qwen3:8b",
    output_file="Results/robot_generated_responses_model_qwen.json",
    excel_file="Data/Elderly_Query.xlsx",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

generator.run()
# Out:
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Generated: What time is it?
# Generated: What’s the weather like today?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
# ...

# %%
from generated_response import RiskAwareResponseGenerator

generator = RiskAwareResponseGenerator(
    model_variant="mistral:7b",
    output_file="Results/robot_generated_responses_model_mistral.json",
    excel_file="Data/Elderly_Query.xlsx",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

generator.run()
# Out:
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Generated: What time is it?
# Generated: What’s the weather like today?
# Generated: Can you open the curtains?
# Generated: Please turn off the television.
# Generated: Can you turn on the lights?
# Generated: Turn off the kitchen light.
# Generated: Can you play the radio?
# Generated: Please switch to the news channel.
# Generated: Lower the air conditioning a little.
# ...
