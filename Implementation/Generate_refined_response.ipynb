# %%
from module_refined_response import RobotResponseRefiner
    
refiner = RobotResponseRefiner(
    model_variant="deepseek-r1:14b",
    output_file="Results/robot_refined_responses_model_deepseek.json",
    
    raw_response_file="Results/robot_raw_responses_model_deepseek.json",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

refiner.run()
# Out:
# Refined: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{ "actio... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Refined: What’s the weather like today?
# Refined: Can you open the curtains?
# Refined: Please turn off the television.
# Refined: Can you turn on the lights?
# Refined: Turn off the kitchen light.
# Refined: Can you play the radio?
# Refined: Please switch to the news channel.
# Refined: Lower the air conditioning a little.
# ...

# %%
from refined_response import RobotResponseRefiner

refiner = RobotResponseRefiner(
    model_variant="phi4:14b",
    output_file="Results/robot_refined_responses_model_phi.json",
    
    raw_response_file="Results/robot_raw_responses_model_phi.json",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

refiner.run()
# Out:
# Refined: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Refined: What’s the weather like today?
# Refined: Can you open the curtains?
# Refined: Please turn off the television.
# Refined: Can you turn on the lights?
# Refined: Turn off the kitchen light.
# Refined: Can you play the radio?
# Refined: Please switch to the news channel.
# Refined: Lower the air conditioning a little.
# ...

# %%
from refined_response import RobotResponseRefiner

refiner = RobotResponseRefiner(
    model_variant="llama3.1:8b",
    output_file="Results/robot_refined_responses_model_llama.json",
    
    raw_response_file="Results/robot_raw_responses_model_llama.json",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

refiner.run()
# Out:
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Refined: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
# ...

# %%
from refined_response import RobotResponseRefiner

refiner = RobotResponseRefiner(
    model_variant="qwen3:8b",
    output_file="Results/robot_refined_responses_model_qwen.json",
    
    raw_response_file="Results/robot_raw_responses_model_qwen.json",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

refiner.run()
# Out:
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{"action... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Refined: What time is it?
# Refined: What’s the weather like today?
# Refined: Can you open the curtains?
# Refined: Please turn off the television.
# Refined: Can you turn on the lights?
# Refined: Turn off the kitchen light.
# Refined: Can you play the radio?
# Refined: Please switch to the news channel.
# Refined: Lower the air conditioning a little.
# ...

# %%
from refined_response import RobotResponseRefiner

refiner = RobotResponseRefiner(
    model_variant="mistral:7b",
    output_file="Results/robot_refined_responses_model_mistral.json",
    
    raw_response_file="Results/robot_raw_responses_model_mistral.json",
    qrs_file="Results/QRS_results.csv",
    api_base="API_KEY_MOBILE_ROBOT"
)

refiner.run()
# Out:
# Refined: What time is it?
# c:\Users\nkelesoglu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "ac... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Refined: What’s the weather like today?
# Refined: Can you open the curtains?
# Refined: Please turn off the television.
# Refined: Can you turn on the lights?
# Refined: Turn off the kitchen light.
# Refined: Can you play the radio?
# Refined: Please switch to the news channel.
# Refined: Lower the air conditioning a little.
# ...
